# %%
from tkinter import *
from tkinter import ttk
from PIL import Image, ImageTk
def calculate(*args):
    try:
        value = float(feet.get())
        meters.set(int(0.3048 * value * 10000.0 + 0.5)/10000.0)
    except ValueError:
        pass

root = Tk()
root.title("Feet to Meters")

mainframe = ttk.Frame(root, padding="3 3 12 12")
mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
root.columnconfigure(0, weight=1)
root.rowconfigure(0, weight=1)

feet = StringVar()
feet_entry = ttk.Entry(mainframe, width=7, textvariable=feet)
feet_entry.grid(column=2, row=1, sticky=(W, E))

meters = StringVar()
ttk.Label(mainframe, textvariable=meters).grid(column=2, row=2, sticky=(W, E))

ttk.Button(mainframe, text="Calculate", command=calculate).grid(column=3, row=3, sticky=W)

ttk.Label(mainframe, text="feet").grid(column=3, row=1, sticky=W)
ttk.Label(mainframe, text="is equivalent to").grid(column=1, row=2, sticky=E)
ttk.Label(mainframe, text="meters").grid(column=3, row=2, sticky=W)

for child in mainframe.winfo_children(): 
    child.grid_configure(padx=25, pady=25)

feet_entry.focus()
root.bind("<Return>", calculate)

root.mainloop()

# %%
import tkinter
from tkinter import *
from PIL import Image, ImageTk

root = Tk()

# Create a photoimage object of the image in the path
image1 = Image.open("./mars.jpg")
test = ImageTk.PhotoImage(image1)

label1 = tkinter.Label(image=test)
label1.image = test

# Position image
label1.place(x=0, y=0)
root.mainloop()

# %%
import tkinter
from tkinter import *
from PIL import Image, ImageTk

root = Tk()

# Position text in frame
Label(root, text='hi' , font =('mars', 5)).pack(side = TOP, padx = 10, pady = 10)

# Create a photoimage object of the image in the path
photo = PhotoImage("./mars.jpg")

# Resize image to fit on button
photoimage = photo.subsample(1, 2)

# Position image on button
Button(root, image = photoimage,).pack(side = BOTTOM, pady = 0)
mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[35], line 17
#      14 photoimage = photo.subsample(1, 2)
#      16 # Position image on button
# ---> 17 Button(root, image = photoimage,).pack(side = BOTTOM, pady = 0)
#      18 mainloop()
#
# File ~/miniconda3/envs/miw/lib/python3.10/tkinter/__init__.py:2679, in Button.__init__(self, master, cnf, **kw)
#    2660 def __init__(self, master=None, cnf={}, **kw):
#    2661     """Construct a button widget with the parent MASTER.
#    2662
#    2663     STANDARD OPTIONS
#    (...)
#    2677         overrelief, state, width
#    2678     """
# -> 2679     Widget.__init__(self, master, 'button', cnf, kw)
#
# File ~/miniconda3/envs/miw/lib/python3.10/tkinter/__init__.py:2601, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2599 for k, v in classes:
#    2600     del cnf[k]
# -> 2601 self.tk.call(
# ...

# %%
from tkinter import *
from tkinter import ttk

def calculate(*args):
    try:
        g1 = float(genetic.get())
        ex1 = float(exercise.get())
        sm1 = float(smoking.get())
        al1 = float(alcohol.get())
        su1 = float(sugar.get())
        bmi1 = float(BMI.get())
        lifespan_advis.set(regCoef[0]*g1)+(regCoef[1]*ex1)+(regCoef[2]*sm1)+(regCoef[3]*al1)+(regCoef[4]*su1)+(regCoef[5]*bmi1)+regInter
    except ValueError:
        pass

root = Tk()
root.title("lifespan calculation")

mainframe = ttk.Frame(root, padding="3 3 12 12")
mainframe.grid(column=0, row=0, sticky=(N, W, E, S))
root.columnconfigure(0, weight=1)
root.rowconfigure(0, weight=1)

g1 = StringVar()
g1_entry = ttk.Entry(mainframe, width=7, textvariable=g1)
g1_entry.grid(column=2, row=1, sticky=(W, E))

ex1 = StringVar()
ex1_entry = ttk.Entry(mainframe, width=7, textvariable=ex1)
ex1_entry.grid(column=2, row=2, sticky=(W, E))

sm1 = StringVar()
sm1_entry = ttk.Entry(mainframe, width=7, textvariable=sm1)
sm1_entry.grid(column=2, row=3, sticky=(W, E))

al1 = StringVar()
al1_entry = ttk.Entry(mainframe, width=7, textvariable=al1)
al1_entry.grid(column=2, row=4, sticky=(W, E))

su1 = StringVar()
su1_entry = ttk.Entry(mainframe, width=7, textvariable=su1)
su1_entry.grid(column=2, row=5, sticky=(W, E))

bmi1 = StringVar()
bmi1_entry = ttk.Entry(mainframe, width=7, textvariable=bmi1)
bmi1_entry.grid(column=2, row=6, sticky=(W, E))


lifespan_advis = StringVar()
ttk.Label(mainframe, textvariable=lifespan_advis).grid(column=2, row=7, sticky=(W, E))

ttk.Button(mainframe, text="Calculate", command=calculate).grid(column=3, row=8, sticky=W)

ttk.Label(mainframe, text="genetic").grid(column=3, row=1, sticky=W)
ttk.Label(mainframe, text="exercise").grid(column=3, row=2, sticky=W)
ttk.Label(mainframe, text="smoking").grid(column=3, row=3, sticky=W)
ttk.Label(mainframe, text="alcohol").grid(column=3, row=4, sticky=W)
ttk.Label(mainframe, text="sugar").grid(column=3, row=5, sticky=W)
ttk.Label(mainframe, text="BMI").grid(column=3, row=6, sticky=W)
ttk.Label(mainframe, text="is lifespan advis").grid(column=1, row=7, sticky=E)
ttk.Label(mainframe, text="years").grid(column=3, row=7, sticky=W)

for child in mainframe.winfo_children(): 
    child.grid_configure(padx=5, pady=5)

g1_entry.focus()
ex1_entry.focus()
sm1_entry.focus()
al1_entry.focus()
su1_entry.focus()
bmi1_entry.focus()
root.bind("<Return>", calculate)

root.mainloop()
