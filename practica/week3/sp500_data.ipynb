# %%
import pandas as pd

# Substitute the path_to_file content by the path to your shopping-data.csv file 
path_to_file = 'sp500_data.csv'
SP500_data = pd.read_csv(path_to_file)

# %%
SP500_data.shape
# Out:
# (5647, 518)

# %%
SP500_data.columns
# Out:
# Index(['Unnamed: 0', 'ADS', 'CA', 'MSFT', 'RHT', 'CTSH', 'CSC', 'EMC', 'IBM',
#        'XRX',
#        ...
#        'WAT', 'ALXN', 'AMGN', 'BXLT', 'BIIB', 'CELG', 'GILD', 'REGN', 'VRTX',
#        'HSIC'],
#       dtype='object', length=518)

# %%
SP500_data['MSFT'].hist()
# Out:
# <Axes: >

# %%
# transpose() transposes the table, making it easier for us to compare values
SP500_data.describe().transpose()
# Out:
#        count      mean       std        min       25%  50%       75%  \
# ADS   5647.0  0.041273  1.291017 -11.240005 -0.130001  0.0  0.200003
# CA    5647.0  0.003379  0.580829  -6.612527 -0.217653  0.0  0.225176
# MSFT  5647.0  0.003065  0.359792  -2.076718 -0.143606  0.0  0.146588
# RHT   5647.0 -0.032918  1.076244 -13.500000 -0.189999  0.0  0.150000
# CTSH  5647.0  0.003007  0.316781  -2.785000 -0.058120  0.0  0.067815
# ...      ...       ...       ...        ...       ...  ...       ...
# CELG  5647.0  0.005226  0.558498  -6.819999 -0.092500  0.0  0.098750
# GILD  5647.0 -0.003724  0.478073  -5.300798 -0.077838  0.0  0.084384
# REGN  5647.0  0.015399  2.376597 -20.490021 -0.379999  0.0  0.375000
# VRTX  5647.0  0.011133  1.204722  -9.187500 -0.389999  0.0  0.375000
# HSIC  5647.0  0.022780  0.621497  -4.690003 -0.250000  0.0  0.305000
#
#             max
# ADS   20.039993
# CA     4.752754
# MSFT   3.490654
# RHT   18.781250
# CTSH   1.994999
# ...         ...
# ...

# %%
SP500_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Columns: 518 entries, Unnamed: 0 to HSIC
# dtypes: float64(517), object(1)
# memory usage: 22.3+ MB

# %%
SP500_data.head()
# Out:
#    Unnamed: 0  ADS        CA      MSFT  RHT  CTSH       CSC       EMC  \
# 0  1993-01-29  0.0  0.060124 -0.022100  0.0   0.0  0.018897  0.007368
# 1  1993-02-01  0.0 -0.180389  0.027621  0.0   0.0  0.018889  0.018425
# 2  1993-02-02  0.0 -0.120257  0.035900  0.0   0.0 -0.075573  0.029482
# 3  1993-02-03  0.0  0.060124 -0.024857  0.0   0.0 -0.151128  0.003689
# 4  1993-02-04  0.0 -0.360770 -0.060757  0.0   0.0  0.113350 -0.022114
#
#         IBM       XRX  ...  WAT  ALXN     AMGN  BXLT     BIIB     CELG  \
# 0  0.092165  0.259140  ...  0.0   0.0  0.34716   0.0  0.04167  0.00000
# 1  0.115207 -0.100775  ...  0.0   0.0 -0.23144   0.0  0.00000 -0.01041
# 2 -0.023041  0.028796  ...  0.0   0.0 -0.11572   0.0  0.00000  0.00000
# 3 -0.253454 -0.043190  ...  0.0   0.0 -0.08679   0.0  0.04167 -0.04167
# 4  0.069862  0.000000  ...  0.0   0.0  0.14465   0.0 -0.04166 -0.03126
#
#        GILD  REGN    VRTX  HSIC
# 0  0.015564  1.75  0.1250   0.0
# 1  0.007782  1.25  0.1250   0.0
# ...

# %%
SP500_data['ADS'].unique()
# Out:
# array([  0.      ,  -0.3     ,   0.26    , ..., -10.299988,  -2.109986,
#         -1.210022])

# %%
SP500_data['CA'].unique()
# Out:
# array([ 0.06012444, -0.18038896, -0.12025659, ..., -0.41      ,
#        -0.049999  ,  0.02      ])

# %%
SP500_data['ADS'].value_counts(normalize=True)
# Out:
#  0.000000    0.381264
# -0.250000    0.005135
#  0.250000    0.004781
#  0.500000    0.003188
# -0.500000    0.003188
#                ...
#  2.330002    0.000177
# -2.799999    0.000177
# -0.320004    0.000177
#  3.220001    0.000177
# -1.210022    0.000177
# Name: ADS, Length: 2162, dtype: float64

# %%
intervals = [-30,-20,-10,-5,-3,-2,-1,0,1,2,3,5,10,20,30]
col = SP500_data['ADS']
SP500_data['ADS Groups'] = pd.cut(x=col, bins=intervals)

# To be able to look at the result stored in the variable
SP500_data['ADS Groups']
# Out:
# 0          (-1, 0]
# 1          (-1, 0]
# 2          (-1, 0]
# 3          (-1, 0]
# 4          (-1, 0]
#            ...
# 5642        (0, 1]
# 5643      (-2, -1]
# 5644    (-20, -10]
# 5645      (-3, -2]
# 5646      (-2, -1]
# Name: ADS Groups, Length: 5647, dtype: category
# Categories (14, interval[int64, right]): [(-30, -20] < (-20, -10] < (-10, -5] < (-5, -3] ... (3, 5] < (5, 10] < (10, 20] < (20, 30]]

# %%
SP500_data.groupby('ADS Groups')['ADS Groups'].count()
# Out:
# ADS Groups
# (-30, -20]       0
# (-20, -10]       4
# (-10, -5]       32
# (-5, -3]        70
# (-3, -2]       102
# (-2, -1]       285
# (-1, 0]       3329
# (0, 1]        1254
# (1, 2]         345
# (2, 3]         100
# (3, 5]          92
# (5, 10]         30
# (10, 20]         3
# (20, 30]         1
# Name: ADS Groups, dtype: int64

# %%
# The _oh means one-hot
SP500_data_oh = pd.get_dummies(SP500_data)
# Display the one-hot encoded dataframe
SP500_data_oh
# Out:
#             ADS        CA      MSFT       RHT      CTSH       CSC       EMC  \
# 0      0.000000  0.060124 -0.022100  0.000000  0.000000  0.018897  0.007368
# 1      0.000000 -0.180389  0.027621  0.000000  0.000000  0.018889  0.018425
# 2      0.000000 -0.120257  0.035900  0.000000  0.000000 -0.075573  0.029482
# 3      0.000000  0.060124 -0.024857  0.000000  0.000000 -0.151128  0.003689
# 4      0.000000 -0.360770 -0.060757  0.000000  0.000000  0.113350 -0.022114
# ...         ...       ...       ...       ...       ...       ...       ...
# 5642   0.019989 -0.529999 -0.379997  0.080002  0.350003 -0.580002 -0.457999
# 5643  -1.299988 -0.330000 -0.390004 -1.820000  0.190003  0.330002 -0.328565
# 5644 -10.299988 -0.410000 -0.670002 -1.250000 -1.919998 -0.510002 -0.139999
# 5645  -2.109986 -0.049999 -0.559997 -0.099999 -0.689999 -0.610001  0.239999
# 5646  -1.210022  0.020000 -0.009998  0.869995  0.329998 -0.190003 -0.039999
#
# ...

# %%
SP500_data_oh = SP500_data_oh.drop(['ADS'], axis=1)
SP500_data_oh.shape
# Out:
# (5647, 6177)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=customer_data['ADS'],
                y=customer_data['CA'])
# Out:
# <Axes: xlabel='ADS', ylabel='CA'>
